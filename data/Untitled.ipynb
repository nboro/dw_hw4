# %%
import pandas as pd

# %%
data = pd.read_csv("bill_join_df.csv",)

# %%
data
# Out:
#        Unnamed: 0                                  song_id             artist  \
# 0               0                  Bohemian_Rhapsody|Queen              Queen
# 1               1                  Bohemian_Rhapsody|Queen              Queen
# 2               2                  Bohemian_Rhapsody|Queen              Queen
# 3               3                  Bohemian_Rhapsody|Queen              Queen
# 4               4                  Bohemian_Rhapsody|Queen              Queen
# ...           ...                                      ...                ...
# 41995       41995            Kissing_a_Fool|George_Michael     George Michael
# 41996       41996       Lay_Your_Weapons_Down|Ilse_DeLange       Ilse DeLange
# 41997       41997                 In_My_Blood|Shawn_Mendes       Shawn Mendes
# 41998       41998      Hold_On_Tight|Solomon_Burke_De_Dijk      Solomon Burke
# 41999       41999  Slaap_zacht_Elisabeth|Acda_en_De_Munnik  Acda en De Munnik
#
# ...
